# %% [markdown]
# ### 1: Experiment with ChatGPT

# %%
from generalfunction import *

# %% [markdown]
# ### 2: Run one example of line charts

# %%
from chatgpt import ChatGPTModel
import pandas as pd

image_path = "/Users/ramihuunguyen/Documents/PhD/Visualization_Literacy/chatgpt_test/test-make-comparison_added_more_elements.png"

question = "Look at each month carefuly. About how much did the price of a barrel of oil fall from April to September in 2015? Options: $4, $15, $17, $45, Omit. Answer only. No explanation."

plot_image(image_path="test-make-comparison_added_more_elements.png")
# Out:
# /Users/ramihuunguyen/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ### 3. Results for 3 times run

# %%
number_of_runs = 3 # 👈 

model = ChatGPTModel()

model.query_multiple_times(question, image_path, times=number_of_runs)

print("The ground truth is $15.")

results = pd.read_csv("linechart_chatgpt_answers.csv")

results
# Out:
# 🧠 Run 1/3
# $15
#
# 🧠 Run 2/3
# $15
#
# 🧠 Run 3/3
# $15
# The ground truth is $15.
#    run answer
# 0    1    $15
# 1    2    $15
# 2    3    $15
