# %%
import pandas as pd

df = pd.read_csv("chartgemma_2_92b_determine_retrieve_value.csv")

pd.set_option('display.max_colwidth', 1000)  # Show all columns

df.head(1).T
# Out:
#                                                                                                                                                                                                  0
# Index                                                                                                                                                                                    img1_run1
# Question Type                                                                                                                                                                       Retrieve Value
# Prompt                                                                                      What was the price of a barrel of oil in February 2015? Options: $57.36, $47.82, $50.24, $39.72, Omit.
# Question Description                                                                        What was the price of a barrel of oil in February 2015? Options: $57.36, $47.82, $50.24, $39.72, Omit.
# ...

# %%
import pandas as pd

df = pd.read_csv("gemini_2_5_pro_determine_retrieve_value.csv")

pd.set_option('display.max_colwidth', 1000)  # Show all columns

df.head(1).T
# Out:
#                                                                                                                                                                        0
# Index                                                                                                                                                          img1_run1
# Question Type                                                                                                                                             Retrieve Value
# Prompt                What was the price of a barrel of oil in February 2015? Options: $57.36, $47.82, $50.24, $39.72, Omit. Choose the accurate answer. No explanation.
# Question Description  What was the price of a barrel of oil in February 2015? Options: $57.36, $47.82, $50.24, $39.72, Omit. Choose the accurate answer. No explanation.
# ...
