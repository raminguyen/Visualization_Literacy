# %% [markdown]
# ### 1: Experiment with Gemini 1.5 Flash

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load and display the image
image_path = "/Users/ramihuunguyen/Documents/PhD/Visualization_Literacy/chatgpt_test/test-make-comparison_added_more_elements.png"
img = Image.open(image_path)

plt.figure(figsize=(10, 6))
plt.imshow(img)
plt.axis('off')
plt.title(" Oil Price Chart (2015)")
plt.show()

# %% [markdown]
# ### 2: Run one example of line charts

# %%
from gemini_1_5_flash import GeminiVisionRunner

# Test parameters
image_file = "/Users/ramihuunguyen/Documents/PhD/Visualization_Literacy/chatgpt_test/test-make-comparison_added_more_elements.png"
prompt_text = "About how much did the price of a barrel of oil fall from April to September in 2015? Options: $4, $15, $17, $45, Omit. Answer only. No explanation."

# Initialize and run
runner = GeminiVisionRunner(
    image_path=image_file,
    prompt=prompt_text,
    runs=3
)

runner.run()
# Out:
# /Users/ramihuunguyen/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 🔁 Run #1
# 🧠 Gemini's Answer: $15
# --------------------------------------------------
# 🔁 Run #2
# 🧠 Gemini's Answer: $15
# --------------------------------------------------
# 🔁 Run #3
# 🧠 Gemini's Answer: $15
# --------------------------------------------------

# %% [markdown]
# ### 3. Results for 3 times run

# %%
import pandas as pd

# Read lines from the output file
with open("gemini_output.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()

# Parse outputs
runs = []
answers = []

for i in range(0, len(lines), 3):
    run_label = lines[i].strip().replace("🔁 ", "")
    answer = lines[i+1].strip()
    runs.append(run_label)
    answers.append(answer)

# Create DataFrame
df = pd.DataFrame({
    "Run": runs,
    "Gemini Answer": answers
})

# Display as table
df.style.set_caption("📊 Gemini Answers Across 3 Runs")
# Out:
# <style type="text/css">
# </style>
# <table id="T_2b6be">
#   <caption>📊 Gemini Answers Across 3 Runs</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b6be_level0_col0" class="col_heading level0 col0" >Run</th>
#       <th id="T_2b6be_level0_col1" class="col_heading level0 col1" >Gemini Answer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b6be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b6be_row0_col0" class="data row0 col0" >Run #1</td>
#       <td id="T_2b6be_row0_col1" class="data row0 col1" >$15</td>
#     </tr>
#     <tr>
#       <th id="T_2b6be_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2b6be_row1_col0" class="data row1 col0" >Run #2</td>
#       <td id="T_2b6be_row1_col1" class="data row1 col1" >$15</td>
#     </tr>
#     <tr>
#       <th id="T_2b6be_level0_row2" class="row_heading level0 row2" >2</th>
# ...
