# %%
import pandas as pd

def summarize_csv(file_path, label=""):
    df = pd.read_csv(file_path)
    total_rows = len(df)
    image_counts = df['Image'].value_counts()
    unique_images = image_counts.shape[0]
    all_five = all(image_counts == 5)

    print(f"\n📂 Summary for {label}")
    print("-" * (20 + len(label)))
    print(f"🧾 Total predictions: {total_rows}")
    print(f"🖼️ Unique images: {unique_images}")
    print(f"🔁 Predictions per image: 5 expected")
    print(f"✅ All images have exactly 5 predictions? {'Yes' if all_five else '❌ No'}")

    if not all_five:
        print("\n⚠️ Images with unexpected prediction counts:")
        print(image_counts[image_counts != 5])

# === Run for each file ===
summarize_csv(
    r"C:\Users\kanam\OneDrive\Desktop\GIT\Visualization_Literacy\AVANITH\Determine_Range\Predictions\Final_chartgemma__Determine_Range.csv",
    "ChartGemma"
)

summarize_csv(
    r"C:\Users\kanam\OneDrive\Desktop\GIT\Visualization_Literacy\AVANITH\Determine_Range\Predictions\Final_chatgpt_Determine_Range.csv",
    "ChatGPT"
)

summarize_csv(
    r"C:\Users\kanam\OneDrive\Desktop\GIT\Visualization_Literacy\AVANITH\Determine_Range\Predictions\Final_gemini_2_5_pro_Determine_Range.csv",
    "Gemini 2.5 Pro"
)

summarize_csv(
    r"C:\Users\kanam\OneDrive\Desktop\GIT\Visualization_Literacy\AVANITH\Determine_Range\Predictions\Final_gemini_flash_Determine_Range.csv",
    "Gemini Flash"
)
# Out:
# 📂 Summary for ChartGemma
# ------------------------------
# 🧾 Total predictions: 50
# 🖼️ Unique images: 10
# 🔁 Predictions per image: 5 expected
# ✅ All images have exactly 5 predictions? Yes
#
# 📂 Summary for ChatGPT
# ---------------------------
# 🧾 Total predictions: 50
# 🖼️ Unique images: 10
# 🔁 Predictions per image: 5 expected
# ✅ All images have exactly 5 predictions? Yes
#
# 📂 Summary for Gemini 2.5 Pro
# ----------------------------------
# 🧾 Total predictions: 50
# 🖼️ Unique images: 10
# 🔁 Predictions per image: 5 expected
# ✅ All images have exactly 5 predictions? Yes
#
# 📂 Summary for Gemini Flash
# --------------------------------
# 🧾 Total predictions: 50
# 🖼️ Unique images: 10
# 🔁 Predictions per image: 5 expected
# ✅ All images have exactly 5 predictions? Yes

# %%
import pandas as pd

def summarize_csv(file_path, label=""):
    df = pd.read_csv(file_path)
    total_rows = len(df)
    image_counts = df['Image'].value_counts()
    unique_images = image_counts.shape[0]
    all_five = all(image_counts == 5)

    print(f"\n📂 Summary for {label}")
    print("-" * (20 + len(label)))
    print(f"🧾 Total predictions: {total_rows}")
    print(f"🖼️ Unique images: {unique_images}")
    print(f"🔁 Predictions per image: 5 expected")
    print(f"✅ All images have exactly 5 predictions? {'Yes' if all_five else '❌ No'}")

    if not all_five:
        print("\n⚠️ Images with unexpected prediction counts:")
        print(image_counts[image_counts != 5])

# === Run for each "Find Correlations" file ===
summarize_csv(
    r"C:\Users\kanam\OneDrive\Desktop\GIT\Visualization_Literacy\AVANITH\Find_Correlations\Predictions\Final_chartgemma__find_correlations.csv",
    "ChartGemma - Find Correlations"
)

summarize_csv(
    r"C:\Users\kanam\OneDrive\Desktop\GIT\Visualization_Literacy\AVANITH\Find_Correlations\Predictions\Final_chatgpt_find_correlations.csv",
    "ChatGPT - Find Correlations"
)

summarize_csv(
    r"C:\Users\kanam\OneDrive\Desktop\GIT\Visualization_Literacy\AVANITH\Find_Correlations\Predictions\Final_gemini_2_5_pro_find_correlations.csv",
    "Gemini 2.5 Pro - Find Correlations"
)

summarize_csv(
    r"C:\Users\kanam\OneDrive\Desktop\GIT\Visualization_Literacy\AVANITH\Find_Correlations\Predictions\Final_gemini_flash_find_correlations.csv",
    "Gemini Flash - Find Correlations"
)
# Out:
# 📂 Summary for ChartGemma - Find Correlations
# --------------------------------------------------
# 🧾 Total predictions: 50
# 🖼️ Unique images: 10
# 🔁 Predictions per image: 5 expected
# ✅ All images have exactly 5 predictions? Yes
#
# 📂 Summary for ChatGPT - Find Correlations
# -----------------------------------------------
# 🧾 Total predictions: 50
# 🖼️ Unique images: 10
# 🔁 Predictions per image: 5 expected
# ✅ All images have exactly 5 predictions? Yes
#
# 📂 Summary for Gemini 2.5 Pro - Find Correlations
# ------------------------------------------------------
# 🧾 Total predictions: 50
# 🖼️ Unique images: 10
# 🔁 Predictions per image: 5 expected
# ✅ All images have exactly 5 predictions? Yes
#
# 📂 Summary for Gemini Flash - Find Correlations
# ----------------------------------------------------
# 🧾 Total predictions: 50
# 🖼️ Unique images: 10
# 🔁 Predictions per image: 5 expected
# ✅ All images have exactly 5 predictions? Yes
