# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\kanam\OneDrive\Desktop\Visualization_Literacy\Visualization_Literacy\Avanith.K\Find_Correlations\chartgemma__find_correlations.csv")
df
# Out:
#                                                Index  \
# 0  line_data.csv_line_Monthly_Oil_Price_History_i...
# 1  line_data.csv_line_Monthly_Oil_Price_History_i...
# 2  line_data.csv_line_Monthly_Oil_Price_History_i...
# 3  line_data.csv_line_Monthly_Oil_Price_History_i...
# 4  line_data.csv_line_Monthly_Oil_Price_History_i...
#
#                                                Image  \
# 0  line_data.csv_line_Monthly_Oil_Price_History_i...
# 1  line_data.csv_line_Monthly_Oil_Price_History_i...
# 2  line_data.csv_line_Monthly_Oil_Price_History_i...
# 3  line_data.csv_line_Monthly_Oil_Price_History_i...
# 4  line_data.csv_line_Monthly_Oil_Price_History_i...
#
#               Question Type  \
# 0  Find Correlations/Trends
# 1  Find Correlations/Trends
# 2  Find Correlations/Trends
# 3  Find Correlations/Trends
# 4  Find Correlations/Trends
#
#                                               Prompt  \
# 0  Over the course of the second half of 2015, th...
# ...

# %%
results_2_5_pro = pd.read_csv(r"C:\Users\kanam\OneDrive\Desktop\Visualization_Literacy\Visualization_Literacy\Avanith.K\Find_Correlations\gemini_2_5_pro_find_correlations.csv")
results_2_5_pro
# Out:
#                                                Index  \
# 0  line_data.csv_line_Monthly_Oil_Price_History_i...
# 1  line_data.csv_line_Monthly_Oil_Price_History_i...
# 2  line_data.csv_line_Monthly_Oil_Price_History_i...
# 3  line_data.csv_line_Monthly_Oil_Price_History_i...
# 4  line_data.csv_line_Monthly_Oil_Price_History_i...
#
#                                                Image  \
# 0  line_data.csv_line_Monthly_Oil_Price_History_i...
# 1  line_data.csv_line_Monthly_Oil_Price_History_i...
# 2  line_data.csv_line_Monthly_Oil_Price_History_i...
# 3  line_data.csv_line_Monthly_Oil_Price_History_i...
# 4  line_data.csv_line_Monthly_Oil_Price_History_i...
#
#               Question Type  \
# 0  Find Correlations/Trends
# 1  Find Correlations/Trends
# 2  Find Correlations/Trends
# 3  Find Correlations/Trends
# 4  Find Correlations/Trends
#
#                                               Prompt  \
# 0  Over the course of the second half of 2015, th...
# ...

# %%
results_2_5_flash = pd.read_csv(r"C:\Users\kanam\OneDrive\Desktop\Visualization_Literacy\Visualization_Literacy\Avanith.K\Find_Correlations\gemini_flash_find_correlations.csv")
results_2_5_flash
# Out:
#                                                Index  \
# 0  line_data.csv_line_Monthly_Oil_Price_History_i...
# 1  line_data.csv_line_Monthly_Oil_Price_History_i...
# 2  line_data.csv_line_Monthly_Oil_Price_History_i...
# 3  line_data.csv_line_Monthly_Oil_Price_History_i...
# 4  line_data.csv_line_Monthly_Oil_Price_History_i...
#
#                                                Image  \
# 0  line_data.csv_line_Monthly_Oil_Price_History_i...
# 1  line_data.csv_line_Monthly_Oil_Price_History_i...
# 2  line_data.csv_line_Monthly_Oil_Price_History_i...
# 3  line_data.csv_line_Monthly_Oil_Price_History_i...
# 4  line_data.csv_line_Monthly_Oil_Price_History_i...
#
#               Question Type  \
# 0  Find Correlations/Trends
# 1  Find Correlations/Trends
# 2  Find Correlations/Trends
# 3  Find Correlations/Trends
# 4  Find Correlations/Trends
#
#                                               Prompt  \
# 0  Over the course of the second half of 2015, th...
# ...

# %%
import pandas as pd; print(pd.read_csv(r"C:\Users\kanam\OneDrive\Desktop\Visualization_Literacy\Visualization_Literacy\Avanith.K\Find_Correlations\chartgemma__find_correlations.csv").columns.tolist())
# Out:
# ['Index', 'Image', 'Question Type', 'Prompt', 'Question Description', 'Model Name', 'Color', 'Chart Title', 'Image Path', 'Ground Truth', 'Prediction', 'Answer Time']

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\kanam\OneDrive\Desktop\Visualization_Literacy\Visualization_Literacy\Avanith.K\Find_Correlations\chatgpt_find_correlations.csv")
df
# Out:
#                                                Index  \
# 0  line_data.csv_line_Monthly_Oil_Price_History_i...
# 1  line_data.csv_line_Monthly_Oil_Price_History_i...
# 2  line_data.csv_line_Monthly_Oil_Price_History_i...
# 3  line_data.csv_line_Monthly_Oil_Price_History_i...
# 4  line_data.csv_line_Monthly_Oil_Price_History_i...
#
#                                                Image  \
# 0  line_data.csv_line_Monthly_Oil_Price_History_i...
# 1  line_data.csv_line_Monthly_Oil_Price_History_i...
# 2  line_data.csv_line_Monthly_Oil_Price_History_i...
# 3  line_data.csv_line_Monthly_Oil_Price_History_i...
# 4  line_data.csv_line_Monthly_Oil_Price_History_i...
#
#               Question Type  \
# 0  Find Correlations/Trends
# 1  Find Correlations/Trends
# 2  Find Correlations/Trends
# 3  Find Correlations/Trends
# 4  Find Correlations/Trends
#
#                                               Prompt  \
# 0  Over the course of the second half of 2015, th...
# ...

# %%
import pandas as pd

# Load the merged CSV file
file_path = r"C:\Users\kanam\OneDrive\Desktop\Visualization_Literacy\Visualization_Literacy\Avanith.K\Find_Correlations\Merged_find_correlations.csv"
df = pd.read_csv(file_path)

# Display first 5 rows
print("🔹 First 5 rows:")
display(df.head())

# Display last 5 rows
print("🔹 Last 5 rows:")
display(df.tail())
# Out:
# 🔹 First 5 rows:
#                                                Index  \
# 0  line_data.csv_line_Monthly_Oil_Price_History_i...
# 1  line_data.csv_line_Monthly_Oil_Price_History_i...
# 2  line_data.csv_line_Monthly_Oil_Price_History_i...
# 3  line_data.csv_line_Monthly_Oil_Price_History_i...
# 4  line_data.csv_line_Monthly_Oil_Price_History_i...
#
#                                                Image  \
# 0  line_data.csv_line_Monthly_Oil_Price_History_i...
# 1  line_data.csv_line_Monthly_Oil_Price_History_i...
# 2  line_data.csv_line_Monthly_Oil_Price_History_i...
# 3  line_data.csv_line_Monthly_Oil_Price_History_i...
# 4  line_data.csv_line_Monthly_Oil_Price_History_i...
#
#               Question Type  \
# 0  Find Correlations/Trends
# 1  Find Correlations/Trends
# 2  Find Correlations/Trends
# 3  Find Correlations/Trends
# 4  Find Correlations/Trends
#
#                                               Prompt  \
# 0  Over the course of the second half of 2015, th...
# ...
