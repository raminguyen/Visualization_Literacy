# %%
import pandas as pd

df = pd.read_csv("/Users/ramihuunguyen/Documents/PhD/Visualization_Literacy/Visualization_Literacy/rami/find_extremum/prediction/chartgemma_2_92b_find_extremum_output.csv")

pd.set_option('display.max_colwidth', None)  # Show all columns

df.head(10)

len(df)
# Out:
# 6

# %%
df.head(50)
# Out:
#    img1_run2  Find Extremum  \
# 0  img1_run3  Find Extremum
# 1  img1_run4  Find Extremum
# 2  img1_run5  Find Extremum
# 3  img2_run1  Find Extremum
# 4  img2_run2  Find Extremum
# 5  img2_run3  Find Extremum
#
#    In which month was the price of a barrel of oil the lowest in 2015? Options: March, May, July, December, Omit.  \
# 0  In which month was the price of a barrel of oil the lowest in 2015? Options: March, May, July, December, Omit.
# 1  In which month was the price of a barrel of oil the lowest in 2015? Options: March, May, July, December, Omit.
# 2  In which month was the price of a barrel of oil the lowest in 2015? Options: March, May, July, December, Omit.
# 3  In which month was the price of a barrel of oil the lowest in 2015? Options: March, May, July, December, Omit.
# 4  In which month was the price of a barrel of oil the lowest in 2015? Options: March, May, July, December, Omit.
# ...

# %%
df['Prediction'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/visualization/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Prediction'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ...
