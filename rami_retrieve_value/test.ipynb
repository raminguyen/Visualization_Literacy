# %%
import pandas as pd

df = pd.read_csv("/Users/ramihuunguyen/Documents/PhD/Visualization_Literacy/retrieve_value/gemini_2_5_pro_determine_retrieve_value.csv")

pd.set_option('display.max_colwidth', None)  # Show all columns

df.head(10)

len(df)
# Out:
# 50

# %%
df.head(50)
# Out:
#          Index   Question Type  \
# 0    img1_run1  Retrieve Value
# 1    img1_run2  Retrieve Value
# 2    img1_run3  Retrieve Value
# 3    img1_run4  Retrieve Value
# 4    img1_run5  Retrieve Value
# 5    img2_run1  Retrieve Value
# 6    img2_run2  Retrieve Value
# 7    img2_run3  Retrieve Value
# 8    img2_run4  Retrieve Value
# 9    img2_run5  Retrieve Value
# 10   img3_run1  Retrieve Value
# 11   img3_run2  Retrieve Value
# 12   img3_run3  Retrieve Value
# 13   img3_run4  Retrieve Value
# 14   img3_run5  Retrieve Value
# 15   img4_run1  Retrieve Value
# 16   img4_run2  Retrieve Value
# 17   img4_run3  Retrieve Value
# 18   img4_run4  Retrieve Value
# 19   img4_run5  Retrieve Value
# 20   img5_run1  Retrieve Value
# 21   img5_run2  Retrieve Value
# 22   img5_run3  Retrieve Value
# 23   img5_run4  Retrieve Value
# 24   img5_run5  Retrieve Value
# 25   img6_run1  Retrieve Value
# 26   img6_run2  Retrieve Value
# 27   img6_run3  Retrieve Value
# 28   img6_run4  Retrieve Value
# ...

# %%
df['Prediction'].unique()
# Out:
# array(['$50.24', '$50.24\n$50.24\n$50.24',
#        '$50.24\n$50.24\n$50.24\n$50.24'], dtype=object)
